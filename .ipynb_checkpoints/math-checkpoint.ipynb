# %%
import math

def bsd(li):
    sum = 0
    variance_sum = 0
    s = li.split(',')
    for i in s:
        sum += int(i)
    average = sum/6
    for i in s:
        variance_sum += pow((int(i) - average),2)
        #variance_sum += (int(i) - average)
        
    return average, (math.sqrt(variance_sum)/6)
    #return average, variance_sum

vectors_set = []

f = open("./luck.csv",'r')
while True:
    line = f.readline()
    if not line: break
    rbsd = bsd(line)
    vectors_set.append([rbsd[0],rbsd[1]])
f.close()
#print vectors_set
x_data = [v[0] for v in vectors_set]
y_data = [v[1] for v in vectors_set]

import matplotlib.pyplot as plt
# %matplotlib inline

#plt.plot(x_data, y_data, 'ro')
#plt.show()

import tensorflow as tf
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.ones([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

init = tf.initialize_all_variables()
sess = tf.Session()
sess.run(init)

for step in range(8):
    sess.run(train)
    print(step, sess.run(W), sess.run(b), sess.run(loss))
    # 산포도 그리기
    plt.plot(x_data, y_data, 'ro')
    # 직선 그리기
    plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
    # x, y 축 레이블링을 하고 각 축의 최대, 최소값 범위를 지정합니다.
    plt.xlabel('x')
    plt.xlim(0,40)
    plt.ylim(0,10)
    plt.ylabel('y')
    plt.show()
# Out:
# (0, array([ 472.99493408], dtype=float32), array([ 21.14722252], dtype=float32), 1.2006519e+08)
# (1, array([-252997.75], dtype=float32), array([-10660.09863281], dtype=float32), 3.4372692e+13)
# (2, array([  1.35367712e+08], dtype=float32), array([ 5704481.5], dtype=float32), 9.8403344e+18)
# (3, array([ -7.24291338e+10], dtype=float32), array([ -3.05221094e+09], dtype=float32), 2.8171268e+24)
# (4, array([  3.87535528e+13], dtype=float32), array([  1.63309958e+12], dtype=float32), 8.0649693e+29)
# (5, array([ -2.07352689e+16], dtype=float32), array([ -8.73797742e+14], dtype=float32), 2.3088683e+35)
# (6, array([  1.10945099e+19], dtype=float32), array([  4.67529490e+17], dtype=float32), inf)
# (7, array([ -5.93617215e+21], dtype=float32), array([ -2.50154077e+20], dtype=float32), inf)
# (8, array([  3.17617740e+24], dtype=float32), array([  1.33846179e+23], dtype=float32), inf)
# (9, array([ -1.69942932e+27], dtype=float32), array([ -7.16150244e+25], dtype=float32), inf)
# (10, array([  9.09287511e+29], dtype=float32), array([  3.83179664e+28], dtype=float32), inf)
# (11, array([ -4.86518482e+32], dtype=float32), array([ -2.05022068e+31], dtype=float32), inf)
# (12, array([  2.60314012e+35], dtype=float32), array([  1.09698002e+34], dtype=float32), inf)
# (13, array([ -1.39282248e+38], dtype=float32), array([ -5.86944602e+36], dtype=float32), inf)
# (14, array([ inf], dtype=float32), array([ inf], dtype=float32), inf)
# (15, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (16, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (17, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (18, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (19, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (20, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (21, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (22, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (23, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (24, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (25, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (26, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (27, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (28, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (29, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (30, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (31, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (32, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (33, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (34, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (35, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (36, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (37, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (38, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (39, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (40, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (41, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (42, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (43, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (44, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (45, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (46, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (47, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (48, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (49, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (50, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (51, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (52, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (53, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (54, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (55, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (56, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (57, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (58, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (59, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (60, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (61, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (62, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (63, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (64, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (65, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (66, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (67, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (68, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (69, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (70, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (71, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (72, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (73, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (74, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (75, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (76, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (77, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (78, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (79, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (80, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (81, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (82, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (83, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (84, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (85, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (86, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (87, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (88, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (89, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (90, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (91, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (92, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (93, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (94, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (95, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# (96, array([ nan], dtype=float32), array([ nan], dtype=float32), nan)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-f056f94157fa> in <module>()
#      59     plt.ylim(0,10)
#      60     plt.ylabel('y')
# ---> 61     plt.show()
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     242     """
#     243     global _show
# --> 244     return _show(*args, **kw)
#     245
#     246
#
# /usr/local/lib/python2.7/dist-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     156             publish_display_data(data=obj, metadata=metadata)
#     157         else:
# --> 158             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     159             if not format_dict:
#     160                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     175             md = None
#     176             try:
# --> 177                 data = formatter(obj)
#     178             except:
#     179                 # FIXME: log the exception
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     220     """show traceback on failed format call"""
#     221     try:
# --> 222         r = method(self, *args, **kwargs)
#     223     except NotImplementedError:
#     224         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     337                 pass
#     338             else:
# --> 339                 return printer(obj)
#     340             # Finally look for special method names
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     224
#     225     if 'png' in formats:
# --> 226         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     227     if 'retina' in formats or 'png2x' in formats:
#     228         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     115
#     116     bytes_io = BytesIO()
# --> 117     fig.canvas.print_figure(bytes_io, **kw)
#     118     data = bytes_io.getvalue()
#     119     if fmt == 'svg':
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2178                     orientation=orientation,
#    2179                     dryrun=True,
# -> 2180                     **kwargs)
#    2181                 renderer = self.figure._cachedRenderer
#    2182                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     525
#     526     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 527         FigureCanvasAgg.draw(self)
#     528         renderer = self.get_renderer()
#     529         original_dpi = renderer.dpi
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1104         renderer.open_group(__name__)
#    1105
# -> 1106         ticks_to_draw = self._update_ticks(renderer)
#    1107         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1108                                                                 renderer)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in _update_ticks(self, renderer)
#     947
#     948         interval = self.get_view_interval()
# --> 949         tick_tups = [t for t in self.iter_ticks()]
#     950         if self._smart_bounds:
#     951             # handle inverted limits
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in iter_ticks(self)
#     891         """
#     892         majorLocs = self.major.locator()
# --> 893         majorTicks = self.get_major_ticks(len(majorLocs))
#     894         self.major.formatter.set_locs(majorLocs)
#     895         majorLabels = [self.major.formatter(val, i)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in get_major_ticks(self, numticks)
#    1292             # update the new tick label properties from the old
#    1293             for i in range(numticks - len(self.majorTicks)):
# -> 1294                 tick = self._get_tick(major=True)
#    1295                 self.majorTicks.append(tick)
#    1296
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1998         else:
#    1999             tick_kw = self._minor_tick_kw
# -> 2000         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2001
#    2002     def _get_label(self):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in _get_tick1line(self)
#     536                           markersize=self._size,
#     537                           markeredgewidth=self._width,
# --> 538                           zorder=self._zorder)
#     539         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     540         self._set_artist_props(l)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     383         self._x_filled = None  # used in subslicing; only x is needed
#     384
# --> 385         self.set_data(xdata, ydata)
#     386
#     387     def __getstate__(self):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/lines.pyc in set_data(self, *args)
#     598             x, y = args
#     599
# --> 600         self.set_xdata(x)
#     601         self.set_ydata(y)
#     602
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/lines.pyc in set_xdata(self, x)
#    1138         """
#    1139         self._xorig = x
# -> 1140         self._invalidx = True
#    1141         self.stale = True
#    1142
#
# KeyboardInterrupt:
